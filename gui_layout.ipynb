# %%
from nicegui import ui

ui.label("Welcome to nicegui!").style("color: green; font-size: 40px")

# Create a greeting
def greet():
    name = input_field.value.strip()
    msg = f"Hello, {name or "stranger"}!"
    ui.notify(msg) # Create a popup

input_field = ui.input("Enter your name")
ui.button("Greet Me!", on_click=greet, color="green")

# Create a counter
class State:
    count = 0
    
count_label = ui.label("Count: 0")

def add_one():
    State.count += slider.value
    
count_label.text = f"Count: {State.count}"

# Greeting card
"""
    with ui.row().classes("w-full"):
        with ui.column().classes("flex-1"):
        input_field = ui.input("Enter your name:" )
        LOOK WHEN HE RELSEASES
"""
    with ui.column().classes("flex-1"):
    #Counter card
        with ui.card().classes("h-65 w-full):
            count_label = ui.label("Count: 0").classes("text-lg")
            # Create a row
            with ui.row():
                ui.button("Add one", color = "blue", on_click = add_one)
                ui.button("Reset", color="red", on_click = reset)
            label_slider = ui.label("Step: 5").classes("text-lg")   # text larger
            slider = ui.slider(min=1, max=10, value = 5)    # min, max, default
            slider.on("update:model-value", lambda: label_slider.set_text(f"Step: {slider.value}"))

n1 = ui.number("Number 1", value = 0).classes("w-24")
ui.label("+").classes("text-lg")
n2.ui.number("Number 2", value=2).classes("w-24")
ui.label("=").classes("text-lg")

ui.switch("Daark mode",
            on_change = lambda e: ui.dark_mode.enable() if e.value else ui.dark_mode().disable())

ui.run(title = "Intro to nicegui")

# TODO
# Create Reset button which sets the counter to 0
ui.button("Add 1", on_click=add_one)
ui.run(title="Simple Greeting App")

# %%
# Page layout
from nicegui import ui

with ui.column():
    ui.label('label 1')
    ui.label('label 2')
    ui.label('label 3')
ui.run()

# record video how your gui is going

# %%
# For assignment, add some feature of GUI that is interesting to you (ex. sound effects)

# %%
from nicegui import ui

with ui.card():
    ui.label('Card content')
    ui.button('Add label', on_click=lambda: ui.label('Click!'))
    ui.timer(1.0, lambda: ui.label('Tick!'), once=True)
# Out:
# disabling auto-reloading because is is only supported when running from a file
# /opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/runners.py:77: RuntimeWarning: coroutine 'Loop.shutdown_asyncgens' was never awaited
#   loop.close()
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/PythProgramming/.venv/lib/python3.11/site-packages/uvicorn/_compat.py:30, in asyncio_run(main, debug, loop_factory)
#      29 with asyncio.Runner(debug=debug, loop_factory=loop_factory) as runner:
# ---> 30     return runner.run(main)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/runners.py:93, in Runner.run(self, coro, context)
#      91 if events._get_running_loop() is not None:
#      92     # fail fast with short traceback
# ---> 93     raise RuntimeError(
#      94         "Runner.run() cannot be called from a running event loop")
#      96 self._lazy_init()
#
# RuntimeError: Runner.run() cannot be called from a running event loop
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 8
#       5     ui.button('Add label', on_click=lambda: ui.label('Click!'))
#       6     ui.timer(1.0, lambda: ui.label('Tick!'), once=True)
# ----> 8 ui.run()
#
# File ~/PythProgramming/.venv/lib/python3.11/site-packages/nicegui/ui_run.py:275, in run(root, host, port, title, viewport, favicon, dark, language, binding_refresh_interval, reconnect_timeout, message_history_length, cache_control_directives, fastapi_docs, show, on_air, native, window_size, fullscreen, frameless, reload, uvicorn_logging_level, uvicorn_reload_dirs, uvicorn_reload_includes, uvicorn_reload_excludes, tailwind, prod_js, endpoint_documentation, storage_secret, session_middleware_kwargs, show_welcome_message, **kwargs)
#     273     Multiprocess(config, target=Server.instance.run, sockets=[sock]).run()
#     274 else:
# --> 275     Server.instance.run()
#     276 if config.uds:
#     277     os.remove(config.uds)  # pragma: py-win32
#
# File ~/PythProgramming/.venv/lib/python3.11/site-packages/nicegui/server.py:37, in Server.run(self, sockets)
#      34     native.response_queue = self.config.response_queue
#      36 storage.set_storage_secret(self.config.storage_secret, self.config.session_middleware_kwargs)
# ---> 37 super().run(sockets=sockets)
#
# File ~/PythProgramming/.venv/lib/python3.11/site-packages/uvicorn/server.py:67, in Server.run(self, sockets)
#      66 def run(self, sockets: list[socket.socket] | None = None) -> None:
# ---> 67     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#
# File ~/PythProgramming/.venv/lib/python3.11/site-packages/uvicorn/_compat.py:29, in asyncio_run(main, debug, loop_factory)
#      21 def asyncio_run(
#      22     main: Coroutine[Any, Any, _T],
#      23     *,
#    (...)     27     # asyncio.run from Python 3.12
#      28     # https://docs.python.org/3/license.html#psf-license
# ---> 29     with asyncio.Runner(debug=debug, loop_factory=loop_factory) as runner:
#      30         return runner.run(main)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/runners.py:63, in Runner.__exit__(self, exc_type, exc_val, exc_tb)
#      62 def __exit__(self, exc_type, exc_val, exc_tb):
# ---> 63     self.close()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/runners.py:72, in Runner.close(self)
#      70     loop = self._loop
#      71     _cancel_all_tasks(loop)
# ---> 72     loop.run_until_complete(loop.shutdown_asyncgens())
#      73     loop.run_until_complete(loop.shutdown_default_executor())
#      74 finally:
#
# File ~/PythProgramming/.venv/lib/python3.11/site-packages/uvloop/loop.pyx:1512, in uvloop.loop.Loop.run_until_complete()
#
# File ~/PythProgramming/.venv/lib/python3.11/site-packages/uvloop/loop.pyx:1505, in uvloop.loop.Loop.run_until_complete()
#
# File ~/PythProgramming/.venv/lib/python3.11/site-packages/uvloop/loop.pyx:1379, in uvloop.loop.Loop.run_forever()
#
# File ~/PythProgramming/.venv/lib/python3.11/site-packages/uvloop/loop.pyx:524, in uvloop.loop.Loop._run()
#
# RuntimeError: Cannot run the event loop while another loop is running
